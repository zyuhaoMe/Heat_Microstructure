# %%
# import libaray
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os
sns.set(rc={"figure.dpi":1600, 'savefig.dpi':1600})
sns.set_theme(style = "white")
# show all rows
pd.set_option('display.max_rows',None)

# %%
# list all the data in the path
path = "./plot_scan_track/"
pathNameList = os.listdir(path)
pathNameList
# Out:
# ['test_data.dat']

# %%
# read and plot one scan path file
xPosList = [];
yPosList = [];
timeList = [];
f = open("./plot_scan_track/"+pathNameList[0], "r")
data = (f.read()).split()
data = list (map(float , data))
totalLen = len(data)
dataArray = np.array(data)
dataArray = dataArray.reshape(-1,3)
dataArray.shape
plt.figure
plt.scatter(dataArray[:,1], dataArray[:,2], s = 0.5)
